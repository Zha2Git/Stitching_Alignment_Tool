# %% [markdown]
# # OmeTiff Stitching  Batch Processing
#
# This notebook provides functions for:
#
# 1. **batch_process_folders(root_path)**: Process all subfolders in a root directory, striching and combine multiple OmeTiff images from each sub directory
#
# Created by Zhang Yang on 2025-12-12

# %% [markdown]
# ## Step 1:  configure File paths

# %%
root_path = r".\test"
exclude_list = ['Combined', '.ome']

# %% [markdown]
# ## Step 2: run Batch Processing

# %%
# Imports
import os
import numpy as np
import pandas as pd
from Tiff_Stitching import (
    OmeTiff_align,
    batch_process_folders,
)
# Run batch processing test
try:
    results = batch_process_folders(root_path, output_suffix="Combined.ome", exclude_files=exclude_list)
    print(f"Processed {len(results)} folder(s)")
    for subfolder, result in results.items():
        if result is not None:
            output_path, combined_array, df_channels = result
            print(f"  ✓ {os.path.basename(subfolder)}: {combined_array.shape}")
        else:
            print(f"  ✗ {os.path.basename(subfolder)}: Failed")
except Exception as e:
    print("Batch test failed:", e)
# Out:
# ################################################################################
# # BATCH PROCESSING STARTED
# # Root path: .\test
# ################################################################################
#
# Found 2 subfolder(s) to process:
#
#   1. Tissue_Panel1
#   2. Tissue_Panel2
#
#
# ================================================================================
# Processing folder 1/2: Tissue_Panel1
# ================================================================================
# ================================================================================
# Processing directory: .\test\Tissue_Panel1
# ================================================================================
#
# [Step 1/7] Reading TIFF files...
# Found 2 TIFF files
# Excluded 0 file(s) matching patterns: ['Combined', '.ome']
# Remaining files: 2
#
# [Step 2/7] Extracting coordinates from filenames...
#
# [Step 3/7] Converting coordinates to grid positions...
#                                                            FileName Position
# 0  20250511_OV, Lung tissues_Scan4_[10978,51596]_component_data.tif   (1, 1)
# 1  20250511_OV, Lung tissues_Scan4_[10978,52292]_component_data.tif   (2, 1)
#
# [Step 4/7] Extracting channel information...
# Extracting channel info from: 20250511_OV, Lung tissues_Scan4_[10978,51596]_component_data.tif
#
# [Method 1] Reading with tifffile - OME-XML metadata:
#   Detected PerkinElmer format
#
# ✓ Successfully extracted 8 channels
# Found 8 channels:
# 0              DAPI (DAPI)
# 1          aSMA (Opal 480)
# 2           CD3 (Opal 520)
# 3          CD68 (Opal 570)
# 4    gamma-H2AX (Opal 620)
# 5           CC3 (Opal 690)
# 6           CD4 (Opal 780)
# 7    AF (Autofluorescence)
#
# [Step 5/7] Combining tiles...
# Grid size: 2 rows x 1 columns
# WARNING:root:File test\Tissue_Panel1\20250511_OV, Lung tissues_Scan4_[10978,51596]_component_data.tif has no OME-XML tags!
# WARNING:root:File test\Tissue_Panel1\20250511_OV, Lung tissues_Scan4_[10978,51596]_component_data.tif has no OME-XML tags!
# Tile dimensions: 8 channels x 1396 x 1860
# Processing: 20250511_OV, Lung tissues_Scan4_[10978,51596]_component_data.tif at position (1, 1)
# Processing: 20250511_OV, Lung tissues_Scan4_[10978,52292]_component_data.tif at position (2, 1)
# WARNING:root:File test\Tissue_Panel1\20250511_OV, Lung tissues_Scan4_[10978,52292]_component_data.tif has no OME-XML tags!
# Combined array shape: (8, 2792, 1860)
#
# [Step 6/7] Building OME metadata (dict)...
#
# [Step 7/7] Saving combined image (OME-TIFF)...
#
# ✓ Successfully saved combined image to: .\test\Tissue_Panel1\Tissue_Panel1_Combined.ome.tif
#   Shape: (8, 2792, 1860)
#   Size: 79.24 MB
# ================================================================================
#
# ✓ Folder 1/2 completed successfully
#
# ================================================================================
# Processing folder 2/2: Tissue_Panel2
# ================================================================================
# ================================================================================
# Processing directory: .\test\Tissue_Panel2
# ================================================================================
#
# [Step 1/7] Reading TIFF files...
# Found 2 TIFF files
# Excluded 0 file(s) matching patterns: ['Combined', '.ome']
# Remaining files: 2
#
# [Step 2/7] Extracting coordinates from filenames...
#
# [Step 3/7] Converting coordinates to grid positions...
#                                                            FileName Position
# 0  20250515_OV, Lung tissues_Scan2_[10881,51565]_component_data.tif   (1, 1)
# 1  20250515_OV, Lung tissues_Scan2_[10881,52261]_component_data.tif   (2, 1)
#
# [Step 4/7] Extracting channel information...
# Extracting channel info from: 20250515_OV, Lung tissues_Scan2_[10881,51565]_component_data.tif
#
# [Method 1] Reading with tifffile - OME-XML metadata:
#   Detected PerkinElmer format
#
# ✓ Successfully extracted 8 channels
# Found 8 channels:
# 0              DAPI (DAPI)
# 1    Granzyme B (Opal 480)
# 2           CD8 (Opal 520)
# 3         panCK (Opal 570)
# 4          Ki67 (Opal 620)
# 5         PD-L1 (Opal 690)
# 6             - (Opal 780)
# 7    AF (Autofluorescence)
#
# [Step 5/7] Combining tiles...
# Grid size: 2 rows x 1 columns
# WARNING:root:File test\Tissue_Panel2\20250515_OV, Lung tissues_Scan2_[10881,51565]_component_data.tif has no OME-XML tags!
# WARNING:root:File test\Tissue_Panel2\20250515_OV, Lung tissues_Scan2_[10881,51565]_component_data.tif has no OME-XML tags!
# Tile dimensions: 8 channels x 1396 x 1860
# Processing: 20250515_OV, Lung tissues_Scan2_[10881,51565]_component_data.tif at position (1, 1)
# Processing: 20250515_OV, Lung tissues_Scan2_[10881,52261]_component_data.tif at position (2, 1)
# WARNING:root:File test\Tissue_Panel2\20250515_OV, Lung tissues_Scan2_[10881,52261]_component_data.tif has no OME-XML tags!
# Combined array shape: (8, 2792, 1860)
#
# [Step 6/7] Building OME metadata (dict)...
#
# [Step 7/7] Saving combined image (OME-TIFF)...
#
# ✓ Successfully saved combined image to: .\test\Tissue_Panel2\Tissue_Panel2_Combined.ome.tif
#   Shape: (8, 2792, 1860)
#   Size: 79.24 MB
# ================================================================================
#
# ✓ Folder 2/2 completed successfully
#
# ################################################################################
# # BATCH PROCESSING COMPLETED
# ################################################################################
#
# Total folders: 2
# Successful: 2
# Failed: 0
#
# ################################################################################
#
# Processed 2 folder(s)
#   ✓ Tissue_Panel1: (8, 2792, 1860)
#   ✓ Tissue_Panel2: (8, 2792, 1860)
